# %% [markdown]
# # Segmentation Visualization — ARTE_371
#
# This notebook plots NSD (Net Squared Displacement, i.e. how far the bird is from home) against time for ARTE_371, colored by which migration phase our system assigned to each point: southbound, wintering, or northbound.
#
# Run this after `pip install matplotlib` if you don't already have it installed.

# %%
import matplotlib.pyplot as plt
import pandas as pd

from bird_dtw.species.arctic_tern.data import fetch_data, load_tracks
from bird_dtw.species.arctic_tern.segmentation.segmentation import segment_track, compute_nsd
