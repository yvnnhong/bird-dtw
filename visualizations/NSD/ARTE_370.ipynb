# %% [markdown]
# # Segmentation Visualization — ARTE_370
#
# This notebook plots NSD (Net Squared Displacement, i.e. how far the bird is from home) against time for ARTE_370, colored by which migration phase our system assigned to each point: southbound, wintering, or northbound.
#
# Run this after `pip install matplotlib` if you don't already have it installed.
